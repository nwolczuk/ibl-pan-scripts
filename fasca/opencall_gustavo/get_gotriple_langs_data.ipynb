# %%
import requests
from urllib.parse import urlencode

import pandas as pd
import json

BASE_API_URL = 'https://api.gotriple.eu/api/'

# %%
def build_api_url(params):
    cleaned_params = {}
    for key, value in params.items():
        if value:
            if isinstance(value, dict):
                cleaned_params[key] = urlencode(value).replace('&', ';')
            else:
               cleaned_params[key] = value
    return urlencode(cleaned_params)

# %%
language = 'other'
provider = 'base'

params = {
    'q': '',
    'fq': {
        'type': 'typ_article',
        # 'has_pdf': 'true',
        'in_language': language,
        # 'provider': provider,
    },
    'include_duplicates': 'false',
    'aggs': {

    },
    # 'sort': 'name:desc', # name, publication_date, most_recent --> name:desc
    'page': 1,
    'size': 100, # max 100
}

# %%
endpoint = 'documents'
objects_list = []
url = f'{BASE_API_URL}{endpoint}?{build_api_url(params)}'
response = requests.get(url)
print('Response length: ', response.json().get('meta').get('total'))
while True:
    response = requests.get(url)
    if not response.ok:
      print('Response error:', response.status_code)
      print(response.text)
      break
    if not response.json()['data']:
      print('Empty "data" field. End of process.')
      break
    else:
        objects_list.extend(response.json()['data'])
        print(url)
        params['page'] += 1
        if params['page'] == 100:
           print('100 pages reached. End of process.')
           break
        url = f'{BASE_API_URL}{endpoint}?{build_api_url(params)}'

print(len(objects_list))
with open(f'gotriple_by_provider/json/gotriple_response_{provider}.json', 'w', encoding='utf-8') as jfile:
    json.dump(objects_list, jfile, indent=4, ensure_ascii=False)
# Out:
# Response length:  1372760
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dundefined&include_duplicates=false&page=1&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dundefined&include_duplicates=false&page=2&size=100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 7
#       5 print('Response length: ', response.json().get('meta').get('total'))
#       6 while True:
# ----> 7     response = requests.get(url)
#       8     if not response.ok:
#       9       print('Response error:', response.status_code)
#
# File c:\Users\nikod\Documents\main_venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\nikod\Documents\main_venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\nikod\Documents\main_venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\nikod\Documents\main_venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\nikod\Documents\main_venv\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File c:\Users\nikod\Documents\main_venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\nikod\Documents\main_venv\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\nikod\Documents\main_venv\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
to_df = []
for obj in objects_list:
    object_id = obj.get('id')

    # in_language - gotriple field
    in_language = ' | '.join(obj.get('in_language'))

    # original_languages
    original_languages = ' | '.join(obj.get('original_languages'))

    # date_published
    date_published = obj.get('date_published')

    # year
    year = date_published[:4] if date_published else ''

    # abstract_present
    abstract_present = True if obj.get('abstract') else False

    # abstract_len
    abstract_len = len(obj.get('abstract')[0].get('text')) if abstract_present else 0

    # keywords_present
    keywords_present = True if obj.get('keywords') else False

    # keyword_count
    keywords_count = len(obj.get('keywords')) if keywords_present else 0

    # source
    source = ' | '.join(obj.get('provider'))

    to_df.append((object_id, in_language, original_languages, date_published, year, abstract_present, abstract_len, keywords_present, keywords_count, source))

df = pd.DataFrame(to_df, columns=['object_id', 'in_language', 'original_languages', 'date_published', 'year', 'abstract_present', 'abstract_len', 'keywords_present', 'keywords_count', 'source'])

df.to_csv(f'gotriple_by_provider/csv/gotriple_response_{provider}.csv', index=False)

# %%
endpoint = 'documents'
objects_list = []
url = f'{BASE_API_URL}{endpoint}?{build_api_url(params)}'
response = requests.get(url)
print('Response length: ', response.json().get('meta').get('total'))
while True:
    response = requests.get(url)
    if not response.ok:
      print('Response error:', response.status_code)
      print(response.text)
      break
    if not response.json()['data']:
      print('Empty "data" field. End of process.')
      break
    else:
        objects_list.extend(response.json()['data'])
        print(url)
        params['page'] += 1
        if params['page'] == 100:
           print('100 pages reached. End of process.')
           break
        url = f'{BASE_API_URL}{endpoint}?{build_api_url(params)}'

print(len(objects_list))
with open(f'gotriple_response_{language}.json', 'w', encoding='utf-8') as jfile:
    json.dump(objects_list, jfile, indent=4, ensure_ascii=False)
# Out:
# Response length:  474963
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=1&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=2&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=3&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=4&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=5&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=6&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=7&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=8&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=9&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=10&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=11&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=12&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=13&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=14&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=15&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=16&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=17&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=18&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=19&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=20&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=21&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=22&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=23&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=24&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=25&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=26&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=27&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=28&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=29&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=30&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=31&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=32&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=33&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=34&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=35&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=36&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=37&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=38&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=39&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=40&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=41&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=42&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=43&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=44&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=45&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=46&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=47&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=48&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=49&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=50&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=51&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=52&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=53&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=54&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=55&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=56&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=57&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=58&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=59&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=60&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=61&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=62&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=63&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=64&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=65&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=66&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=67&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=68&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=69&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=70&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=71&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=72&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=73&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=74&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=75&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=76&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=77&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=78&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=79&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=80&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=81&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=82&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=83&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=84&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=85&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=86&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=87&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=88&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=89&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=90&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=91&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=92&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=93&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=94&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=95&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=96&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=97&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=98&size=100
# https://api.gotriple.eu/api/documents?fq=type%3Dtyp_article%3Bin_language%3Dother&include_duplicates=false&page=99&size=100
# 100 pages reached. End of process.
# 9900

# %%
to_df = []
for obj in objects_list:
    object_id = obj.get('id')

    # in_language - gotriple field
    in_language = ' | '.join(obj.get('in_language'))

    # original_languages
    original_languages = ' | '.join(obj.get('original_languages'))

    # date_published
    date_published = obj.get('date_published')

    # year
    year = date_published[:4] if date_published else ''

    # abstract_present
    abstract_present = True if obj.get('abstract') else False

    # abstract_len
    abstract_len = len(obj.get('abstract')[0].get('text')) if abstract_present else 0

    # keywords_present
    keywords_present = True if obj.get('keywords') else False

    # keyword_count
    keywords_count = len(obj.get('keywords')) if keywords_present else 0

    # source
    source = ' | '.join(obj.get('provider'))

    to_df.append((object_id, in_language, original_languages, date_published, year, abstract_present, abstract_len, keywords_present, keywords_count, source))

df = pd.DataFrame(to_df, columns=['object_id', 'in_language', 'original_languages', 'date_published', 'year', 'abstract_present', 'abstract_len', 'keywords_present', 'keywords_count', 'source'])

df.to_csv(f'gotriple_response_{language}.csv', index=False)
